# %%
W
# Out:
# Hill Climbing:
# Best solution: x=283, y=961.9537148736761
# Best value: 0.8086513048432343
# New Hill Climbing:
# Best solution: x=283.82123551682, y=818.2256427922072
# Best value: 0.8070364374361066
